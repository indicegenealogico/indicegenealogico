# %%
import pandas as pd
import sqlite3 as db

# %%
conn = db.connect('db.sqlite3')
df_pp = pd.read_sql_query('select * from people_person', conn)

# %%
df_pp
# Out:
#           id   forename middle_names known_as             surname maiden_name  \
# 0          1       Luis        Ramon                      Maestre
# 1          2    Teodora        Maria                       Cedeño
# 2          3     Carmen        Maria           Hernandez Gonzalez
# 3          4  Francisca    Saturnina               Moya Hernandez
# 4          5    Eusebio       Adrian              Martinez Garcia
# ...      ...        ...          ...      ...                 ...         ...
# 68463  68464    Rosendo       Alvino               Bonillo Guerra
# 68464  68465      Maria      Rosario              Espinoza Garcia
# 68465  68466       Luis      Beltran                       Farias
# 68466  68467    Brigida                                    Farias
# 68467  68468      Pablo   Deogracias                        Bravo
#
#       gender  deceased notes  birth_id  death_id father_id mother_id  user_id
# ...

# %%
df_pp.plot()
# Out:
# <AxesSubplot:>
